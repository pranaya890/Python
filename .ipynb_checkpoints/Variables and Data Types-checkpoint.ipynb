# %%
x = 5
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
y = "Hello World"
print(y)
print(type(y))
# Out:
# Hello World
# <class 'str'>

# %%
z = True
print(type(z))
# Out:
# <class 'bool'>

# %%
a = 4.3
print(a)
print(type(a))
# Out:
# 4.3
# <class 'float'>
