# %%
x = 5
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
y = "Hello World"
print(y)
print(type(y))
# Out:
# Hello World
# <class 'str'>

# %%
z = True
print(type(z))
# Out:
# <class 'bool'>

# %%
a = 4.3
print(a)
print(type(a))
# Out:
# 4.3
# <class 'float'>

# %%
type(x-1)
type(x+1)
# Out:
# int

# %%
print(x+3)
print(x-1)
# Out:
# 8
# 4

# %%
#Data Type conversion
x1 = float(x)
print(x1)
print(type(x1))
a1=int(a)
print(a1)
print(type(a1))
print(type(a1+4.3))#adding float to int]

#adding int to float
a2 = 12.3
print(type(a2))
print(a2+15)
print(type(a2+15))
# Out:
# 5.0
# <class 'float'>
# 4
# <class 'int'>
# <class 'float'>
# <class 'float'>
# 27.3
# <class 'float'>
